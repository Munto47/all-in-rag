# %%
from unstructured.partition.pdf import partition_pdf
from unstructured.partition.auto import partition

# PDF文件路径
pdf_path = "../../data/C2/pdf/rag.pdf"

# 使用Unstructured加载并解析PDF文档
elements = partition_pdf(
    filename=pdf_path,
    content_type="application/pdf",
    strategy="ocr_only",
    languages=["chi_sim", "eng"]
)
# Out:
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# short text: "fomieas tat OACe @". Defaulting to English.
# short text: "it =". Defaulting to English.
# short text: "[= = RAGFlow". Defaulting to English.
# short text: "RAG". Defaulting to English.
# short text: "an, UETARMEMERS Hid |,". Defaulting to English.
# short text: "QD AlterBPAER -". Defaulting to English.
# short text: "Retriever". Defaulting to English.
# short text: "Generator". Defaulting to English.
# short text: "e} odelScope". Defaulting to English.
# short text: "Result". Defaulting to English.
# short text: "ur". Defaulting to English.
# short text: "RAG AIGC ( )". Defaulting to English.
# short text: "?". Defaulting to English.
# short text: "simayi315 (2025-02-27". Defaulting to English.
# short text: "RAG". Defaulting to English.
# short text: "RAG RAG RAG RAG". Defaulting to English.
# short text: "RAG". Defaulting to English.
# short text: "4]". Defaulting to English.
# short text: "2]". Defaulting to English.
# short text: "(QA Systems):". Defaulting to English.
# short text: ": Retrieval)". Defaulting to English.
# short text: "HTML to PDF". Defaulting to English.
# short text: "|),". Defaulting to English.
# short text: "RAG". Defaulting to English.
# short text: "RAG RAG RAG". Defaulting to English.
# short text: "HTML to PDF". Defaulting to English.
# short text: "an =". Defaulting to English.
# short text: "QD Arteria". Defaulting to English.
# short text: "a". Defaulting to English.
# short text: "1 @ Q". Defaulting to English.
# No features in text.
# short text: "Balter +". Defaulting to English.
# short text: ">". Defaulting to English.
# short text: "NEW". Defaulting to English.

# %%
print(f"解析完成: {len(elements)} 个元素, {sum(len(str(e)) for e in elements)} 字符")
# Out:
# 解析完成: 105 个元素, 2380 字符

# %%
# 打印解析结果

# 统计元素类型
from collections import Counter
types = Counter(e.category for e in elements)
print(f"元素类型: {dict(types)}")

# 显示所有元素
print("\n所有元素:")
for i, element in enumerate(elements, 1):
    print(f"Element {i} ({element.category}):")
    print(element)
    print("=" * 60)
# Out:
# 元素类型: {'Title': 63, 'NarrativeText': 7, 'UncategorizedText': 35}
#
# 所有元素:
# Element 1 (Title):
# 页 Se 知道 Be BR 视频 文库 资讯 采购 百科 SR ith
# ============================================================
# Element 2 (Title):
# 6@ | x 本 | mm
# ============================================================
# Element 3 (NarrativeText):
# 首页 ! pias > 1 REA 增 Otte Lew
# ============================================================
# Element 4 (NarrativeText):
# fomieas tat OACe @
# ============================================================
# Element 5 (NarrativeText):
# it =
# ============================================================
# Element 6 (Title):
# [= = RAGFlow
# ============================================================
# Element 7 (Title):
# RAG: = ERIS TEA pares
# ============================================================
# Element 8 (UncategorizedText):
# 。 RAG ARH 检 (Retrievalaugmented Generation) ",
# ============================================================
# Element 9 (UncategorizedText):
# aN < 四。 e € =|
# ============================================================
# Element 10 (UncategorizedText):
# 有 加 11 3 本 简 称 Retrieval-augmented Generation RAG ; Hs 1 aa 9 限制 Ee EAR’ Ny 42 ay 谐 2 RAG FEL NE AF Logit fy RAG BESTS RAG 4 6 7 10 8 IR 教授 5 查
# ============================================================
# Element 11 (Title):
# 是 播报
# ============================================================
# Element 12 (Title):
# Al Generation for Knowledge-Intensive NLP
# ============================================================
# Element 13 (Title):
# RAG
# ============================================================
# Element 14 (Title):
# RAG RAG ( pre-retrieval and post-retrieval strategies )
# ============================================================
# Element 15 (Title):
# : 技术 | 从 RAG RAG 让 AI “FNP
# ============================================================
# Element 16 (UncategorizedText):
# an, UETARMEMERS Hid |,
# ============================================================
# Element 17 (Title):
# QD AlterBPAER -
# ============================================================
# Element 18 (NarrativeText):
# 有 播报 ) ( RetrevahAugmented Generation, RAG) ® eae eee
# ============================================================
# Element 19 (UncategorizedText):
# 。 中]
# ============================================================
# Element 20 (UncategorizedText):
# Explore our developer-friendly HTML to PDF API Printed using PDFCrowd HTML to PDF
# ============================================================
# Element 21 (Title):
# 是
# ============================================================
# Element 22 (Title):
# Q) 播报
# ============================================================
# Element 23 (UncategorizedText):
# RAG 四。
# ============================================================
# Element 24 (Title):
# 。 K
# ============================================================
# Element 25 (UncategorizedText):
# 。
# ============================================================
# Element 26 (UncategorizedText):
# 。
# ============================================================
# Element 27 (Title):
# Retriever
# ============================================================
# Element 28 (UncategorizedText):
# 2 Users Input L L ®@ SD) encote (D) Hugging Face & Index Gopenal Gemini stability.ai
# ============================================================
# Element 29 (Title):
# Generator
# ============================================================
# Element 30 (Title):
# e} odelScope
# ============================================================
# Element 31 (Title):
# Result
# ============================================================
# Element 32 (UncategorizedText):
# []。
# ============================================================
# Element 33 (Title):
# Q) 播报
# ============================================================
# Element 34 (UncategorizedText):
# RAG 整个 办。
# ============================================================
# Element 35 (Title):
# ur
# ============================================================
# Element 36 (UncategorizedText):
# RAG AIGC ( )
# ============================================================
# Element 37 (Title):
# 等 Transformer Stable Codex 办。
# ============================================================
# Element 38 (Title):
# 。 Transformer (LSTM ) (GAN )
# ============================================================
# Element 39 (Title):
# 四。
# ============================================================
# Element 40 (UncategorizedText):
# (LSTM，Long Short-Term Memory ) ( ) |,
# ============================================================
# Element 41 (UncategorizedText):
# ( 加。
# ============================================================
# Element 42 (UncategorizedText):
# ) ( GAN 四。
# ============================================================
# Element 43 (UncategorizedText):
# ) ( 由。
# ============================================================
# Element 44 (Title):
# 。 四
# ============================================================
# Element 45 (UncategorizedText):
# (ANN) 办。
# ============================================================
# Element 46 (UncategorizedText):
# ?
# ============================================================
# Element 47 (UncategorizedText):
# simayi315 (2025-02-27
# ============================================================
# Element 48 (Title):
# 54hehezi A\ 四
# ============================================================
# Element 49 (Title):
# Explore our developer-friendly HTML to PDF API
# ============================================================
# Element 50 (NarrativeText):
# Printed using PDFCrowd HTML to PDF
# ============================================================
# Element 51 (Title):
# § qh 播报
# ============================================================
# Element 52 (Title):
# RAG
# ============================================================
# Element 53 (Title):
# RAG RAG RAG RAG
# ============================================================
# Element 54 (Title):
# 基于 的 RAG Logit RAG
# ============================================================
# Element 55 (Title):
# 的 Logit RAG Logit Logit 外。 RAG
# ============================================================
# Element 56 (Title):
# RAG
# ============================================================
# Element 57 (UncategorizedText):
# 4]
# ============================================================
# Element 58 (Title):
# 是 qh 播报
# ============================================================
# Element 59 (UncategorizedText):
# 2]
# ============================================================
# Element 60 (Title):
# 是 Qn 播报
# ============================================================
# Element 61 (Title):
# (QA Systems):
# ============================================================
# Element 62 (Title):
# : ( Document Generation and Automatic Summarization )
# ============================================================
# Element 63 (Title):
# : (Intelligent Assistants and Virtual Agents )
# ============================================================
# Element 64 (Title):
# : Retrieval)
# ============================================================
# Element 65 (Title):
# : 5 ( Knowledge Graph Population ) 加。
# ============================================================
# Element 66 (Title):
# 目 ah 播报
# ============================================================
# Element 67 (Title):
# Explore our developer-friendly HTML to PDF API Printed using PDFCrowd
# ============================================================
# Element 68 (Title):
# HTML to PDF
# ============================================================
# Element 69 (UncategorizedText):
# 6 加。
# ============================================================
# Element 70 (UncategorizedText):
# RAG 限制 Q) 播报 〈 )
# ============================================================
# Element 71 (Title):
# 四。
# ============================================================
# Element 72 (Title):
# 四。
# ============================================================
# Element 73 (UncategorizedText):
# |),
# ============================================================
# Element 74 (Title):
# | FLIRAY_E F3Z C)) 播报
# ============================================================
# Element 75 (Title):
# RAG
# ============================================================
# Element 76 (NarrativeText):
# 是 a) 播报 四。
# ============================================================
# Element 77 (Title):
# RAG 管道
# ============================================================
# Element 78 (Title):
# RAG RAG RAG
# ============================================================
# Element 79 (Title):
# RAG RAG RAG 虽然
# ============================================================
# Element 80 (UncategorizedText):
# RAG AIGC ( ) 办。
# ============================================================
# Element 81 (Title):
# RAG RAG RAG 概 LLM 及
# ============================================================
# Element 82 (Title):
# Explore our developer-friendly HTML to PDF API Printed using PDFCrowd
# ============================================================
# Element 83 (Title):
# HTML to PDF
# ============================================================
# Element 84 (Title):
# an =
# ============================================================
# Element 85 (NarrativeText):
# : ONE 各 =e) [Se [oor | aX 一 =
# ============================================================
# Element 86 (Title):
# RAG 让 Al 从 BRE" !
# ============================================================
# Element 87 (Title):
# 普通 Al 是 RAG RAG
# ============================================================
# Element 88 (Title):
# QD Arteria
# ============================================================
# Element 89 (Title):
# a
# ============================================================
# Element 90 (UncategorizedText):
# 1 @ Q
# ============================================================
# Element 91 (UncategorizedText):
# 2 @ ! % .
# ============================================================
# Element 92 (Title):
# ) 3 ( % . GPTSecurity |
# ============================================================
# Element 93 (Title):
# 4 @ [2402.19473v6] Retrieval-Generated Content: ASurvey % . anxiv
# ============================================================
# Element 94 (Title):
# 5 国 [1706.03762] Attention Is All You Need q . arxiv
# ============================================================
# Element 95 (Title):
# 6 @ [2009.06732] Efficient Transformers: A Survey % . arxiv
# ============================================================
# Element 96 (UncategorizedText):
# 7 @ Long Short-Term Memory | MIT Press Journals & Magazine % . IEEE Xplore
# ============================================================
# Element 97 (UncategorizedText):
# 8 @ [2209.00796] Diffusion Models: A Comprehensive Survey of Methods and Applications q . arxiv
# ============================================================
# Element 98 (UncategorizedText):
# 9 @ [2001.06937v1] A Review on Generative Adversarial Networks: Algorithms, Theory, and Applications % . arxiv
# ============================================================
# Element 99 (UncategorizedText):
# 10 @ [2311.15578] Experimental Analysis of Large-scale Learnable Vector Storage Compression Q% . arxiv
# ============================================================
# Element 100 (Title):
# Balter +
# ============================================================
# Element 101 (UncategorizedText):
# >
# ============================================================
# Element 102 (Title):
# 加 中
# ============================================================
# Element 103 (Title):
# NEW
# ============================================================
# Element 104 (UncategorizedText):
# @2025 Baidu | | | | @
# ============================================================
# Element 105 (UncategorizedText):
# Explore our developer-friendly HTML to PDF API Printed using PDFCrowd H to PDF
# ============================================================

# %%
elements
# Out:
# [<unstructured.documents.elements.Title at 0x29c51bdd580>,
#  <unstructured.documents.elements.Title at 0x29c51396090>,
#  <unstructured.documents.elements.NarrativeText at 0x29c51669a30>,
#  <unstructured.documents.elements.NarrativeText at 0x29c814ff230>,
#  <unstructured.documents.elements.NarrativeText at 0x29c55e5edb0>,
#  <unstructured.documents.elements.Title at 0x29c516cf320>,
#  <unstructured.documents.elements.Title at 0x29c814fc920>,
#  <unstructured.documents.elements.Text at 0x29c814ff6e0>,
#  <unstructured.documents.elements.Text at 0x29c814a7b30>,
#  <unstructured.documents.elements.Text at 0x29c814a7b90>,
#  <unstructured.documents.elements.Title at 0x29c814a54f0>,
#  <unstructured.documents.elements.Title at 0x29c814a4fe0>,
#  <unstructured.documents.elements.Title at 0x29c814a68a0>,
#  <unstructured.documents.elements.Title at 0x29c814a5eb0>,
#  <unstructured.documents.elements.Title at 0x29c814a6c60>,
#  <unstructured.documents.elements.Text at 0x29c814a7320>,
#  <unstructured.documents.elements.Title at 0x29c814a7140>,
#  <unstructured.documents.elements.NarrativeText at 0x29c814a58b0>,
#  <unstructured.documents.elements.Text at 0x29c814a6000>,
#  <unstructured.documents.elements.Text at 0x29c814a57c0>,
#  <unstructured.documents.elements.Title at 0x29c814a6de0>,
#  <unstructured.documents.elements.Title at 0x29c814a69c0>,
#  <unstructured.documents.elements.Text at 0x29c814a73e0>,
#  <unstructured.documents.elements.Title at 0x29c55e5d190>,
#  <unstructured.documents.elements.Text at 0x29c51a7be30>,
#  <unstructured.documents.elements.Text at 0x29c51a7af90>,
#  <unstructured.documents.elements.Title at 0x29c51491520>,
#  <unstructured.documents.elements.Text at 0x29c51492ba0>,
#  <unstructured.documents.elements.Title at 0x29c517ecb30>,
#  <unstructured.documents.elements.Title at 0x29c51c2d9d0>,
#  <unstructured.documents.elements.Title at 0x29c7e67ed20>,
#  <unstructured.documents.elements.Text at 0x29c7e67eb10>,
#  <unstructured.documents.elements.Title at 0x29c7e67f050>,
#  <unstructured.documents.elements.Text at 0x29c814a5010>,
#  <unstructured.documents.elements.Title at 0x29c814a5040>,
#  <unstructured.documents.elements.Text at 0x29c7e67e9f0>,
#  <unstructured.documents.elements.Title at 0x29c51c4db50>,
#  <unstructured.documents.elements.Title at 0x29c55e55af0>,
#  <unstructured.documents.elements.Title at 0x29c55e5cfe0>,
#  <unstructured.documents.elements.Text at 0x29c814a5cd0>,
#  <unstructured.documents.elements.Text at 0x29c513e5400>,
#  <unstructured.documents.elements.Text at 0x29c513e52b0>,
#  <unstructured.documents.elements.Text at 0x29c513e7500>,
#  <unstructured.documents.elements.Title at 0x29c51669ee0>,
#  <unstructured.documents.elements.Text at 0x29c51b305c0>,
#  <unstructured.documents.elements.Text at 0x29c51b83c20>,
#  <unstructured.documents.elements.Text at 0x29c5166bb30>,
#  <unstructured.documents.elements.Title at 0x29c814ff5c0>,
#  <unstructured.documents.elements.Title at 0x29c51afedb0>,
#  <unstructured.documents.elements.NarrativeText at 0x29c814a45c0>,
#  <unstructured.documents.elements.Title at 0x29c55e568a0>,
#  <unstructured.documents.elements.Title at 0x29c51c04260>,
#  <unstructured.documents.elements.Title at 0x29c51bea570>,
#  <unstructured.documents.elements.Title at 0x29c51b5a210>,
#  <unstructured.documents.elements.Title at 0x29c51b4df40>,
#  <unstructured.documents.elements.Title at 0x29c51b4dca0>,
#  <unstructured.documents.elements.Text at 0x29c51a4d1c0>,
#  <unstructured.documents.elements.Title at 0x29c814fdc10>,
#  <unstructured.documents.elements.Text at 0x29c814a5fd0>,
#  <unstructured.documents.elements.Title at 0x29c814a6090>,
#  <unstructured.documents.elements.Title at 0x29c51ba3bc0>,
#  <unstructured.documents.elements.Title at 0x29c513c8320>,
#  <unstructured.documents.elements.Title at 0x29c513cb4a0>,
#  <unstructured.documents.elements.Title at 0x29c814f62a0>,
#  <unstructured.documents.elements.Title at 0x29c513c8170>,
#  <unstructured.documents.elements.Title at 0x29c51c61a30>,
#  <unstructured.documents.elements.Title at 0x29c51c62b70>,
#  <unstructured.documents.elements.Title at 0x29c51bc9370>,
#  <unstructured.documents.elements.Text at 0x29c51c97950>,
#  <unstructured.documents.elements.Text at 0x29c814f5580>,
#  <unstructured.documents.elements.Title at 0x29c55e54ef0>,
#  <unstructured.documents.elements.Title at 0x29c51b65e20>,
#  <unstructured.documents.elements.Text at 0x29c51b06bd0>,
#  <unstructured.documents.elements.Title at 0x29c51b04c80>,
#  <unstructured.documents.elements.Title at 0x29c514295b0>,
#  <unstructured.documents.elements.NarrativeText at 0x29c513c91c0>,
#  <unstructured.documents.elements.Title at 0x29c51bb6810>,
#  <unstructured.documents.elements.Title at 0x29c51b6fad0>,
#  <unstructured.documents.elements.Title at 0x29c51b6cef0>,
#  <unstructured.documents.elements.Text at 0x29c814f7770>,
#  <unstructured.documents.elements.Title at 0x29c814f5b20>,
#  <unstructured.documents.elements.Title at 0x29c814f7410>,
#  <unstructured.documents.elements.Title at 0x29c814f5cd0>,
#  <unstructured.documents.elements.Title at 0x29c55e5fd40>,
#  <unstructured.documents.elements.NarrativeText at 0x29c7e6886e0>,
#  <unstructured.documents.elements.Title at 0x29c55e5e570>,
#  <unstructured.documents.elements.Title at 0x29c814fcf20>,
#  <unstructured.documents.elements.Title at 0x29c814a7aa0>,
#  <unstructured.documents.elements.Title at 0x29c814a77d0>,
#  <unstructured.documents.elements.Text at 0x29c814ffc80>,
#  <unstructured.documents.elements.Text at 0x29c814a7dd0>,
#  <unstructured.documents.elements.Title at 0x29c513e4890>,
#  <unstructured.documents.elements.Title at 0x29c814a46b0>,
#  <unstructured.documents.elements.Title at 0x29c814a6030>,
#  <unstructured.documents.elements.Title at 0x29c7e67ef90>,
#  <unstructured.documents.elements.Text at 0x29c513e7830>,
#  <unstructured.documents.elements.Text at 0x29c814a44d0>,
#  <unstructured.documents.elements.Text at 0x29c814a4560>,
#  <unstructured.documents.elements.Text at 0x29c51a8d880>,
#  <unstructured.documents.elements.Title at 0x29c814a4230>,
#  <unstructured.documents.elements.Text at 0x29c814a50d0>,
#  <unstructured.documents.elements.Title at 0x29c814a7800>,
#  <unstructured.documents.elements.Title at 0x29c814a7b00>,
#  <unstructured.documents.elements.Text at 0x29c814f54f0>,
#  <unstructured.documents.elements.Text at 0x29c51b6e810>]
